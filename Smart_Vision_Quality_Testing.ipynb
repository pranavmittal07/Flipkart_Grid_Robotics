# %% [markdown]
# ## Downloading the required dependencies

# %%
# !python -m pip install git+https://github.com/huggingface/transformers
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-a9h3ahb1
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-a9h3ahb1
#   Resolved https://github.com/huggingface/transformers to commit f1b7634fc840a96198268eb9b3d61b92b05c7cfb
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.26.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (2024.8.30)
# Looking in indexes: https://download.pytorch.org/whl/cu117
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# ## Importing Model From Hugging Face

# %%
import openpyxl
import cv2
import os
import torch
from PIL import Image
import requests
from io import BytesIO
import json
from transformers import AutoProcessor, AutoModelForCausalLM, Qwen2VLForConditionalGeneration
from base64 import b64decode
from IPython.display import display, Javascript
from google.colab.output import eval_js
from datetime import datetime, timedelta
import re


# Load the Qwen2 model and processor
model = Qwen2VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2-VL-2B-Instruct",
    torch_dtype="auto",
    device_map="auto",
)

processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-2B-Instruct")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/56.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]

# %% [markdown]
# ## Initialise Excel File and Necessary Functions to Prcoess Data

# %%
import pytz

# Define the Excel file path
file_path = "product_analysis.xlsx"

# Initialize workbook and sheets
if os.path.exists(file_path):
    workbook = openpyxl.load_workbook(file_path)
    if "Packaged Products" in workbook.sheetnames:
        packaged_sheet = workbook["Packaged Products"]
    else:
        packaged_sheet = workbook.create_sheet("Packaged Products")
    if "Fresh Produce" in workbook.sheetnames:
        produce_sheet = workbook["Fresh Produce"]
    else:
        produce_sheet = workbook.create_sheet("Fresh Produce")
else:
    workbook = openpyxl.Workbook()
    packaged_sheet = workbook.active
    packaged_sheet.title = "Packaged Products"
    produce_sheet = workbook.create_sheet("Fresh Produce")

    # Add headers for Packaged Products
    packaged_headers = ["Sl No", "Timestamp", "Brand", "Count", "Expiry Date", "Expired", "Expected Life Span (Days)"]
    packaged_sheet.append(packaged_headers)

    # Add headers for Fresh Produce
    produce_headers = ["Sl No", "Timestamp", "Produce Name", "Freshness (1-10)", "Expected Life Span (Days)"]
    produce_sheet.append(produce_headers)

# Initialize row counters
packaged_sl_no = len(packaged_sheet['A']) if len(packaged_sheet['A']) > 1 else 1
produce_sl_no = len(produce_sheet['A']) if len(produce_sheet['A']) > 1 else 1

# Function to get the current timestamp in IST
def get_ist_timestamp():
    # Define IST time zone
    IST = pytz.timezone('Asia/Kolkata')

    # Get current time in UTC and convert to IST
    utc_now = datetime.now(pytz.utc)
    ist_now = utc_now.astimezone(IST)

    # Return the formatted timestamp
    return ist_now.strftime("%Y-%m-%d %H:%M:%S")


def normalize_date(date_str):
    """
    Normalize various date formats to 'YYYY-MM-DD'.
    """
    patterns = [
        "%d-%m-%Y", "%d/%m/%Y", "%d/%m/%y", "%m/%y", "%b %Y", "%b-%Y"
    ]

    for pattern in patterns:
        try:
            normalized_date = datetime.strptime(date_str, pattern)

            # For MM/YY format, assume the 1st day of the month
            if pattern == "%m/%y":
                normalized_date = normalized_date.replace(day=1)

            return normalized_date.strftime("%Y-%m-%d")
        except ValueError:
            continue
    return "Invalid Date"


def calculate_expiration(expiry_date, mfg_date=None, best_before=None):
    """
    Calculate expiration status and expected life span.
    """
    today = datetime.today()

    if expiry_date:
        normalized_expiry_date = normalize_date(expiry_date)
        if normalized_expiry_date != "Invalid Date":
            expiry_date_obj = datetime.strptime(normalized_expiry_date, "%Y-%m-%d")

            if expiry_date_obj < today:
                expired_status = 1
                expected_life_span = 0
            else:
                expired_status = 0
                expected_life_span = (expiry_date_obj - today).days
            return normalized_expiry_date, expired_status, expected_life_span

    if mfg_date and best_before:
        normalized_mfg_date = normalize_date(mfg_date)
        if normalized_mfg_date != "Invalid Date":
            expiry_date_obj = datetime.strptime(normalized_mfg_date, "%Y-%m-%d")
            expiry_date_obj += timedelta(days=int(best_before) * 30)
            normalized_expiry_date = expiry_date_obj.strftime("%Y-%m-%d")

            if expiry_date_obj < today:
                expired_status = 1
                expected_life_span = 0
            else:
                expired_status = 0
                expected_life_span = (expiry_date_obj - today).days
            return normalized_expiry_date, expired_status, expected_life_span

    return False, 0, "Invalid Date"


def append_to_excel(product_details_dict):
    global packaged_sl_no, produce_sl_no
    timestamp = timestamp = get_ist_timestamp()
    # Print the product details dictionary to debug
    print(f"Received Product Details: {product_details_dict}")

    if product_details_dict.get("type") == "Packed Product":
        packaged_sl_no += 1
        brand = product_details_dict.get("Brand", "Unknown")
        product_count = product_details_dict.get("Product Count", 0)
        expiry_date = product_details_dict.get("Expiry Date", None)
        mfg_date = product_details_dict.get("Manufacturing Date", None)
        best_before = product_details_dict.get("Best Before Months", None)

        # Call the modified calculate_expiration function
        normalized_expiry_date, expired_status, expected_life_span = calculate_expiration(
            expiry_date, mfg_date, best_before
        )

        # Append to the "Packaged Products" sheet
        packaged_sheet.append([
            packaged_sl_no,
            timestamp,
            brand,
            product_count,
            normalized_expiry_date,  # Use normalized expiry date
            expired_status,  # Expired (1) or Not Expired (0)
            expected_life_span  # Expected life span in days
        ])

    elif product_details_dict.get("type") == "Fresh Product":
        produce_sl_no += 1
        produce_name = product_details_dict.get("Produce Name", "Unknown")
        freshness = product_details_dict.get("Freshness", "Unknown")
        expected_life_span = product_details_dict.get("Expected Life Span (Days)", "Unknown")

        # Append to the "Fresh Produce" sheet
        produce_sheet.append([
            produce_sl_no,
            timestamp,
            produce_name,
            freshness,
            expected_life_span  # Expected life span (days)
        ])
    else:
        print("Error: Invalid product type")

    # Save the workbook after appending the product details
    workbook.save(file_path)


def process_image(image):
    """
    Process the image and extract product details using Qwen model.
    """
    image = image.resize((512, 512))

    # Prepare the text prompt for Qwen model to get general product details
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "image_url": "Captured from webcam"},
                {
                    "type": "text",
                    "text": """Analyze this image fetch the details of below & return the Python dictionary format:
                    If it contains packaged products, include:
                    {
                        "type": "Packed Product",
                        "Brand": "string",
                        "Product Count": int,
                        "Expiry Date": "string", (maybe found with Exp date, use by)
                        "Mfg Date": "string", (maybe found with mfg date)
                        "Best Before Months": int  # If 'Best Before months & Use By' is mentioned else None.
                    }

                    If it contains fresh produce, include:
                    {
                        "type": "Fresh Product",
                        "Produce Name": "string",
                        "Freshness": int,  # Based on visual clues (e.g., color, ripeness, bruising, etc.). 1-10 scale with dull color fruit image score less and bright & shiny score more don't give 8 to all.
                        "Expected Life Span (Days)": int  # Estimate based on visual signs of freshness and decay. It should be varied with images not simply marked
                    }
                    """
                }
            ]
        }
    ]


    # Prepare the text prompt for processing
    text_prompt = processor.apply_chat_template(messages, add_generation_prompt=True)

    # Process the image and prompt for model input
    inputs = processor(
        text=[text_prompt],
        images=[image],
        padding=True,
        return_tensors="pt"
    )

    # Move inputs to GPU if available
    inputs = inputs.to("cuda" if torch.cuda.is_available() else "cpu")

    # Generate output from the model
    output_ids = model.generate(**inputs, max_new_tokens=1024)

    # Decode the generated output
    generated_ids = [
        output_ids[len(input_ids):]
        for input_ids, output_ids in zip(inputs.input_ids, output_ids)
    ]
    output_text = processor.batch_decode(
        generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True
    )[0]

    print("Model Output:", output_text)

    # Parse the output as a dictionary and append to Excel
    try:
        product_details_dict = eval(output_text)  # Assuming the model returns a Python dictionary as a string
        append_to_excel(product_details_dict)
        print("Product details saved successfully.")
    except Exception as e:
        print(f"Error processing output: {e}")


def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
      async function takePhoto(quality) {
        const div = document.createElement('div');
        const capture = document.createElement('button');
        capture.textContent = 'Capture';
        div.appendChild(capture);

        const video = document.createElement('video');
        video.style.display = 'block';
        const stream = await navigator.mediaDevices.getUserMedia({video: true});

        document.body.appendChild(div);
        div.appendChild(video);
        video.srcObject = stream;
        await video.play();

        // Resize the output to fit the video element.
        google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

        // Wait for Capture to be clicked.
        await new Promise((resolve) => capture.onclick = resolve);

        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getVideoTracks()[0].stop();
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
      }
      ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = b64decode(data.split(',')[1])
    with open(filename, 'wb') as f:
      f.write(binary)
    return filename

# Function to Capture and Process Image from Webcam
def capture_and_process_image():
    try:
        filename = take_photo()
        print('Saved to {}'.format(filename))

        # Show the image which was just taken.
        display(IPImage(filename))
        # Open the image file
        image = Image.open(filename)

        # Process the image
        process_image(image)
    except Exception as err:
        print(str(err))


# Function to Upload and Process Image from Local System
def upload_and_process_image():
    try:
        # Prompt the user to upload an image file
        uploaded = files.upload()

        if not uploaded:
            print("No file uploaded.")
            return

        # Get the uploaded file name
        for filename in uploaded.keys():
            print(f'Uploaded file: {filename}')
            # Open the image file
            image = Image.open(BytesIO(uploaded[filename]))

            # Process the image
            process_image(image)
    except Exception as err:
        print(f"Error processing uploaded image: {err}")

# %% [markdown]
# # => Final Function to Run Each Time (For Camera)

# %%
capture_and_process_image()

# %% [markdown]
# # => Final Function to Run Each Time (For Uploading)

# %%
upload_and_process_image()

# %% [markdown]
# # Debug File

# %%
image = Image.open('1.png')
process_image(image)
# Out:
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Maybelline",
#     "Product Count": 3,
#     "Expiry Date": "2019.01.01",
#     "Mfg Date": "2018.02.02",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Maybelline', 'Product Count': 3, 'Expiry Date': '2019.01.01', 'Mfg Date': '2018.02.02', 'Best Before Months': None}
# Product details saved successfully.

# %%
from PIL import Image
import os

# Folder containing images
image_folder = '/content/'  # Replace this with your directory path

# Loop through all the files in the directory
for filename in os.listdir(image_folder):
    # Check if the file is an image (you can add more file extensions as needed)
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        # Create the full path to the image file
        image_path = os.path.join(image_folder, filename)

        # Open the image using PIL
        image = Image.open(image_path)

        # Process the image
        print(f"Processing {filename}...")
        process_image(image)
# Out:
# Processing 20240929_235441.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Best Before 06/2023",
#     "Mfg Date": "2023-06-01",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Best Before 06/2023', 'Mfg Date': '2023-06-01', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_154925.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "22/01/25",
#     "Mfg Date": "22/01/25",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': '22/01/25', 'Mfg Date': '22/01/25', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_154835.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "18/09/24",
#     "Mfg Date": "15/01/25",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': '18/09/24', 'Mfg Date': '15/01/25', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240930_001535.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Crax",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-01",
#     "Mfg Date": "2023-03-20",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Crax', 'Product Count': 1, 'Expiry Date': '2023-04-01', 'Mfg Date': '2023-03-20', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155013.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155618.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Hakiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Hakiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240930_001549.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Crax",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-15",
#     "Mfg Date": "2023-04-15",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Crax', 'Product Count': 1, 'Expiry Date': '2023-04-15', 'Mfg Date': '2023-04-15', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235458.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Dabur",
#     "Product Count": 1,
#     "Expiry Date": "2023-08-15",
#     "Mfg Date": "2023-08-14",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Dabur', 'Product Count': 1, 'Expiry Date': '2023-08-15', 'Mfg Date': '2023-08-14', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241001_170812.jpg...
# Model Output: {
#     "type": "Fresh Product",
#     "Produce Name": "Ginger",
#     "Freshness": 8,
#     "Expected Life Span (Days)": 10
# }
# Received Product Details: {'type': 'Fresh Product', 'Produce Name': 'Ginger', 'Freshness': 8, 'Expected Life Span (Days)': 10}
# Product details saved successfully.
# Processing 20241002_160020.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Hokiram's",
#     "Product Count": 2,
#     "Expiry Date": "09/01/24",
#     "Mfg Date": "09/01/24",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Hokiram's", 'Product Count': 2, 'Expiry Date': '09/01/24', 'Mfg Date': '09/01/24', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235521.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "None",
#     "Product Count": 1,
#     "Expiry Date": "None",
#     "Mfg Date": "None",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'None', 'Product Count': 1, 'Expiry Date': 'None', 'Mfg Date': 'None', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235632.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Nestle",
#     "Product Count": 1,
#     "Expiry Date": "2023-05-15",
#     "Mfg Date": "2023-05-15",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Nestle', 'Product Count': 1, 'Expiry Date': '2023-05-15', 'Mfg Date': '2023-05-15', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235613.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235405.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Nestle",
#     "Product Count": 1,
#     "Expiry Date": "17/1/25 11:08",
#     "Mfg Date": "2017/19 124419",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Nestle', 'Product Count': 1, 'Expiry Date': '17/1/25 11:08', 'Mfg Date': '2017/19 124419', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_153816.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235505.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "CreamBell",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-15",
#     "Mfg Date": "2023-04-15",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'CreamBell', 'Product Count': 1, 'Expiry Date': '2023-04-15', 'Mfg Date': '2023-04-15', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155048.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "04/09/22",
#     "Mfg Date": "01/01/23",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': '04/09/22', 'Mfg Date': '01/01/23', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235509.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Devani",
#     "Product Count": 1,
#     "Expiry Date": "2023-03-15",
#     "Mfg Date": "2023-03-15",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Devani', 'Product Count': 1, 'Expiry Date': '2023-03-15', 'Mfg Date': '2023-03-15', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235426.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Biryana",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-01",
#     "Mfg Date": "2023-03-25",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Biryana', 'Product Count': 1, 'Expiry Date': '2023-04-01', 'Mfg Date': '2023-03-25', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241001_170816.jpg...
# Model Output: {
#     "type": "Fresh Product",
#     "Produce Name": "Ginger",
#     "Freshness": 8,
#     "Expected Life Span (Days)": 10
# }
# Received Product Details: {'type': 'Fresh Product', 'Produce Name': 'Ginger', 'Freshness': 8, 'Expected Life Span (Days)': 10}
# Product details saved successfully.
# Processing 20241002_155208.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 1,
#     "Expiry Date": "Best Before 05/2023",
#     "Mfg Date": "2023-05-01",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 1, 'Expiry Date': 'Best Before 05/2023', 'Mfg Date': '2023-05-01', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_154953.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "HALDIRAM SNACKS PVT. LTD.",
#     "Product Count": 1,
#     "Expiry Date": "09/09/24",
#     "Mfg Date": "09/09/24",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'HALDIRAM SNACKS PVT. LTD.', 'Product Count': 1, 'Expiry Date': '09/09/24', 'Mfg Date': '09/09/24', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155917.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "15/01/18",
#     "Mfg Date": "18/09/24",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': '15/01/18', 'Mfg Date': '18/09/24', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235557.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Anmol",
#     "Product Count": 1,
#     "Expiry Date": "08/08/2024",
#     "Mfg Date": "08/08/2024",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Anmol', 'Product Count': 1, 'Expiry Date': '08/08/2024', 'Mfg Date': '08/08/2024', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155822.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 20,
#     "Expiry Date": "11/10/2021",
#     "Mfg Date": "14/09/2021",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 20, 'Expiry Date': '11/10/2021', 'Mfg Date': '14/09/2021', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155027.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 5,
#     "Expiry Date": "09/24",
#     "Mfg Date": "31/12/24",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 5, 'Expiry Date': '09/24', 'Mfg Date': '31/12/24', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155537.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "HALDIRAM SNACKS",
#     "Product Count": 1,
#     "Expiry Date": "22/09/24",
#     "Mfg Date": "19/01/25",
#     "Best Before Months": None,
#     "Net Quantity": 20,
#     "Mfg Batch": "1000001100123456",
#     "Use By": "19/01/25",
#     "Batch": "1000001100123456",
#     "MRP": "Rs. 5.00",
#     "All Taxes": "Rs. 5.00",
#     "USP": "Ready-to-Eat Savoury Snacks"
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'HALDIRAM SNACKS', 'Product Count': 1, 'Expiry Date': '22/09/24', 'Mfg Date': '19/01/25', 'Best Before Months': None, 'Net Quantity': 20, 'Mfg Batch': '1000001100123456', 'Use By': '19/01/25', 'Batch': '1000001100123456', 'MRP': 'Rs. 5.00', 'All Taxes': 'Rs. 5.00', 'USP': 'Ready-to-Eat Savoury Snacks'}
# Product details saved successfully.
# Processing 20241002_155059.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241001_170604.jpg...
# Model Output: {
#     "type": "Fresh Product",
#     "Produce Name": "甜菜",
#     "Freshness": 8,
#     "Expected Life Span (Days)": 10
# }
# Received Product Details: {'type': 'Fresh Product', 'Produce Name': '甜菜', 'Freshness': 8, 'Expected Life Span (Days)': 10}
# Product details saved successfully.
# Processing 20240929_235516.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Priyagold",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Priyagold', 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_160254.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Frost It",
#     "Product Count": 1,
#     "Expiry Date": "since 1985",
#     "Mfg Date": "1985",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Frost It', 'Product Count': 1, 'Expiry Date': 'since 1985', 'Mfg Date': '1985', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_160302.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Frooti",
#     "Product Count": 1,
#     "Expiry Date": "since 1985",
#     "Mfg Date": "1985",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Frooti', 'Product Count': 1, 'Expiry Date': 'since 1985', 'Mfg Date': '1985', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235619.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 1,
#     "Expiry Date": "2024-01-12",
#     "Mfg Date": "2023-12-24",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 1, 'Expiry Date': '2024-01-12', 'Mfg Date': '2023-12-24', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_154806.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Out of date",
#     "Mfg Date": "Out of date",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Out of date', 'Mfg Date': 'Out of date', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_154938.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_153555.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 5,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 5, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_160155.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 1,
#     "Expiry Date": "Best Before",
#     "Mfg Date": "2023-04-01",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 1, 'Expiry Date': 'Best Before', 'Mfg Date': '2023-04-01', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155108.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Milto",
#     "Product Count": 2,
#     "Expiry Date": "Best Before 4 Months",
#     "Mfg Date": "2022-04-01",
#     "Best Before Months": 4,
#     "Nutritional Facts": {
#         "Energy": 510kJ,
#         "Protein": 2g,
#         "Carbohydrate": 4g,
#         "Fiber": 0g,
#         "Fat": 3g,
#         "Saturated Fat": 0g,
#         "MUFA": 12.3g,
#         "PUFA": 1.3g,
#         "Total Fat": 5g,
#         "Sodium": 510mg
#     }
# }
# Error processing output: invalid decimal literal (<string>, line 9)
# Processing 20241002_155520.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Best Before 06/2023",
#     "Mfg Date": "2023-06-01",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Best Before 06/2023', 'Mfg Date': '2023-06-01', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241001_170410.jpg...
# Model Output: {
#     "type": "Fresh Product",
#     "Produce Name": "Fresh Produce",
#     "Freshness": 8,
#     "Expected Life Span (Days)": 10
# }
# Received Product Details: {'type': 'Fresh Product', 'Produce Name': 'Fresh Produce', 'Freshness': 8, 'Expected Life Span (Days)': 10}
# Product details saved successfully.
# Processing 20241002_155746.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241001_170146.jpg...
# Model Output: {
#     "type": "Fresh Product",
#     "Produce Name": "Green Cucumber",
#     "Freshness": 8,
#     "Expected Life Span (Days)": 10
# }
# Received Product Details: {'type': 'Fresh Product', 'Produce Name': 'Green Cucumber', 'Freshness': 8, 'Expected Life Span (Days)': 10}
# Product details saved successfully.
# Processing 20240929_235526.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Surya Food & Agro Ltd.",
#     "Product Count": 1,
#     "Expiry Date": "May 25",
#     "Mfg Date": "Aug 24",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Surya Food & Agro Ltd.', 'Product Count': 1, 'Expiry Date': 'May 25', 'Mfg Date': 'Aug 24', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_160206.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Milto",
#     "Product Count": 50,
#     "Expiry Date": "09/30/21",
#     "Mfg Date": "09/30/21",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Milto', 'Product Count': 50, 'Expiry Date': '09/30/21', 'Mfg Date': '09/30/21', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241001_170620.jpg...
# Model Output: {
#     "type": "Fresh Product",
#     "Produce Name": "Red Sweet Potato",
#     "Freshness": 8,
#     "Expected Life Span (Days)": 10
# }
# Received Product Details: {'type': 'Fresh Product', 'Produce Name': 'Red Sweet Potato', 'Freshness': 8, 'Expected Life Span (Days)': 10}
# Product details saved successfully.
# Processing 20241002_155647.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "19/08/24",
#     "Mfg Date": "16/12/24",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': '19/08/24', 'Mfg Date': '16/12/24', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_153636.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155950.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155906.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiyan",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Haldiyan', 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240930_001526.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Evita",
#     "Product Count": 1,
#     "Expiry Date": "2023-03-15",
#     "Mfg Date": "2023-03-15",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Evita', 'Product Count': 1, 'Expiry Date': '2023-03-15', 'Mfg Date': '2023-03-15', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241001_170113.jpg...
# Model Output: ```python
# {
#     "type": "Fresh Product",
#     "Produce Name": "Cucumber",
#     "Freshness": 8,
#     "Expected Life Span (Days)": 10
# }
# ```
# Error processing output: invalid syntax (<string>, line 1)
# Processing 20240929_235551.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Anmol",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-01",
#     "Mfg Date": "2023-03-20",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Anmol', 'Product Count': 1, 'Expiry Date': '2023-04-01', 'Mfg Date': '2023-03-20', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155040.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240930_001545.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Max",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-15",
#     "Mfg Date": "2023-04-15",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Max', 'Product Count': 1, 'Expiry Date': '2023-04-15', 'Mfg Date': '2023-04-15', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235601.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Cadbury",
#     "Product Count": 1,
#     "Expiry Date": "2023-05-15",
#     "Mfg Date": "2023-05-15",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Cadbury', 'Product Count': 1, 'Expiry Date': '2023-05-15', 'Mfg Date': '2023-05-15', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_153648.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Hakkarams",
#     "Product Count": 1,
#     "Expiry Date": "12/01/2024",
#     "Mfg Date": "10/17/2017",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Hakkarams', 'Product Count': 1, 'Expiry Date': '12/01/2024', 'Mfg Date': '10/17/2017', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_155415.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Morano",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Morano', 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235501.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Cream Bell",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Cream Bell', 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240929_235357.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Parle",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-01",
#     "Mfg Date": "2023-03-20",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Parle', 'Product Count': 1, 'Expiry Date': '2023-04-01', 'Mfg Date': '2023-03-20', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_154902.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Haldiram's",
#     "Product Count": 1,
#     "Expiry Date": "Not applicable",
#     "Mfg Date": "Not applicable",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': "Haldiram's", 'Product Count': 1, 'Expiry Date': 'Not applicable', 'Mfg Date': 'Not applicable', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20240930_001518.jpg...
# Model Output: {
#     "type": "Packed Product",
#     "Brand": "Evita",
#     "Product Count": 1,
#     "Expiry Date": "2023-04-01",
#     "Mfg Date": "2023-03-20",
#     "Best Before Months": None
# }
# Received Product Details: {'type': 'Packed Product', 'Brand': 'Evita', 'Product Count': 1, 'Expiry Date': '2023-04-01', 'Mfg Date': '2023-03-20', 'Best Before Months': None}
# Product details saved successfully.
# Processing 20241002_153603.jpg...

# %% [markdown]
# Old Code (below) - Phase I

# %%
# Create a new Excel workbook
workbook = openpyxl.Workbook()
sheet = workbook.active
sheet.title = "Product Analysis"

# Add headers
headers = ["Product Name", "Category", "Quantity", "Count", "Expiry Date", "Freshness Index", "Shelf Life"]
sheet.append(headers)

# Regular expression patterns to extract data
packaged_product_pattern = r"Product Name: (.*)\n  - Product Category: (.*)\n  - Product Quantity: (.*)\n  - Product Count: (.*)\n  - Expiry Date: (.*)"
fruits_vegetables_pattern = r"Type of fruit/vegetable: (.*)\n  - Freshness Index: (.*)\n  - Estimated Shelf Life: (.*)"

from PIL import Image
import os

# Folder containing images
image_folder = '/content/'  # Replace this with your directory path

# Loop through all the files in the directory
for filename in os.listdir(image_folder):
    # Check if the file is an image (you can add more file extensions as needed)
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        # Create the full path to the image file
        image_path = os.path.join(image_folder, filename)


        # Open the image using PIL
        image = Image.open(image_path)
        image = image.resize((512, 512))

        # Prepare the text prompt for predicting product details and freshness
        messages = [
            {
                "role": "user",
                "content": [
                    {
                        "type": "image",
                        "image_url": "Captured from webcam"  # Description for internal use
                    },
                    {
                        "type": "text",
                        "text": """This image contains fruits, vegetables, or packaged products.
                        Please analyze the image and provide:
                        - For packaged products:
                            - Product Name
                            - Product Category
                            - Product Quantity
                            - Product Count
                            - Expiry Date (if available)
                        - For fruits and vegetables:
                            - Type of fruit/vegetable
                            - Freshness Index (based on visual cues)
                            - Estimated Shelf Life"""
                    }
                ]
            }
        ]

        # Prepare the text prompt for processing
        text_prompt = processor.apply_chat_template(messages, add_generation_prompt=True)

        # Process the image and prompt for model input
        inputs = processor(
            text=[text_prompt],
            images=[image],
            padding=True,
            return_tensors="pt"
        )

        # Move inputs to GPU if available
        inputs = inputs.to("cuda" if torch.cuda.is_available() else "cpu")

        # Generate output from the model
        output_ids = model.generate(**inputs, max_new_tokens=1024)

        # Decode the generated output
        generated_ids = [
            output_ids[len(input_ids):]
            for input_ids, output_ids in zip(inputs.input_ids, output_ids)
        ]
        output_text = processor.batch_decode(
            generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True
        )[0]

        # Print the output text for the current image
        print(f"Analysis Output for the captured frame:")
        print(output_text)

        # Extract packaged product information
        packaged_product_match = re.search(packaged_product_pattern, output_text)
        fruits_vegetables_match = re.search(fruits_vegetables_pattern, output_text)

        if packaged_product_match:
            product_name = packaged_product_match.group(1).strip()
            category = packaged_product_match.group(2).strip()
            quantity = packaged_product_match.group(3).strip()
            count = packaged_product_match.group(4).strip()
            expiry_date = packaged_product_match.group(5).strip()
        else:
            product_name = category = quantity = count = expiry_date = "N/A"

        if fruits_vegetables_match:
            # Overwrite product fields with fruit/vegetable data if applicable
            product_name = fruits_vegetables_match.group(1).strip()
            category = "Fruit/Vegetable"
            freshness_index = fruits_vegetables_match.group(2).strip()
            shelf_life = fruits_vegetables_match.group(3).strip()
        else:
            freshness_index = shelf_life = "N/A"

        # Insert row into Excel
        sheet.append([product_name, category, quantity, count, expiry_date, freshness_index, shelf_life])

# Save the workbook
workbook.save("product_analysis.xlsx")
print("Data saved to product_analysis.xlsx")
# Out:
# Analysis Output for the captured frame:
# - **For packaged products:**
#   - **Product Name:** Haldiram's Panga Achaari Masala
#   - **Product Category:** Snacks
#   - **Product Quantity:** 1 pack
#   - **Product Count:** 1
#   - **Expiry Date:** Not visible in the image
#
# - **For fruits and vegetables:**
#   - **Type of fruit/vegetable:** Not applicable as the image shows a packaged product, not a fresh fruit or vegetable.
#   - **Freshness Index:** Not applicable as the image does not provide any visual cues about freshness.
#   - **Estimated Shelf Life:** Not applicable as the image does not provide any information about the shelf life of the product.
# Analysis Output for the captured frame:
# - **For packaged products:**
#   - **Product Name:** Haldiram's Aloo Bhujia
#   - **Product Category:** Snacks
#   - **Product Quantity:** 20g
#   - **Product Count:** 1
#   - **Expiry Date:** 22/01/25
#
# - **For fruits and vegetables:**
#   - **Type of fruit/vegetable:** Aloo (Potato)
#   - **Freshness Index:** Based on visual cues, the potato appears to be fresh and unblemished.
#   - **Estimated Shelf Life:** The potato is likely to remain fresh for several days after purchase, but it is best to check its freshness periodically.
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Haldiram's Bhujia
#   - Product Category: Snacks
#   - Product Quantity: 1 pack
#   - Product Count: 1
#   - Expiry Date: 18/09/24
# - For fruits and vegetables:
#   - Type of fruit/vegetable: Not applicable (as it is a packaged product)
#   - Freshness Index: Not applicable (as it is a packaged product)
#   - Estimated Shelf Life: Not applicable (as it is a packaged product)
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Crax Curls
#   - Product Category: Snacks
#   - Product Quantity: 1 pack
#   - Product Count: 1
#   - Expiry Date: Not visible in the image
#
# - For fruits and vegetables:
#   - Type of fruit/vegetable: Corn
#   - Freshness Index: The image does not provide any visual cues to determine the freshness of the corn. Therefore, it is not possible to estimate the shelf life of the corn based on the image alone.
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Morano Jhal Mudi
#   - Product Category: Snacks
#   - Product Quantity: 1 pack
#   - Product Count: 1
#   - Expiry Date: Not visible in the image
#
# - For fruits and vegetables:
#   - Type of fruit/vegetable: Jhal Mudi (a type of lentil snack)
#   - Freshness Index: The image does not provide any visual cues to determine the freshness of the Jhal Mudi. Therefore, it is not possible to estimate the shelf life of the Jhal Mudi based on the image alone.
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Chatpata Dal
#   - Product Category: Snacks
#   - Product Quantity: 1 pack
#   - Product Count: 1
#   - Expiry Date: Not visible in the image
#
# - For fruits and vegetables:
#   - Type of fruit/vegetable: Not applicable, as it is a packaged product
#   - Freshness Index: Not applicable, as it is a packaged product
#   - Estimated Shelf Life: Not applicable, as it is a packaged product
# Analysis Output for the captured frame:
# - **For packaged products:**
#   - **Product Name:** Crax Curls
#   - **Product Category:** Snacks
#   - **Product Quantity:** 16 g
#   - **Product Count:** 1
#   - **Expiry Date:** Not visible in the image
#
# - **For fruits and vegetables:**
#   - **Type of fruit/vegetable:** Corn Curls
#   - **Freshness Index:** Not applicable as it is a packaged product
#   - **Estimated Shelf Life:** Not applicable as it is a packaged product
# Analysis Output for the captured frame:
# - **For packaged products:**
#   - **Product Name:** Unilever Well
#   - **Product Category:** Beverages
#   - **Product Quantity:** 1 bottle
#   - **Product Count:** 1
#   - **Expiry Date:** Not visible in the image
#
# - **For fruits and vegetables:**
#   - **Type of fruit/vegetable:** Not applicable (as it is a packaged product)
#   - **Freshness Index:** Not applicable (as it is a packaged product)
#   - **Estimated Shelf Life:** Not applicable (as it is a packaged product)
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Ginger
#   - Product Category: Herbs and Spices
#   - Product Quantity: 2 pieces
#   - Product Count: 2
#   - Expiry Date: Not applicable (as ginger is a fresh, non-perishable product)
#
# - For fruits and vegetables:
#   - Type of fruit/vegetable: Ginger
#   - Freshness Index: The ginger appears to be fresh and unblemished, indicating it is likely in good condition.
#   - Estimated Shelf Life: Ginger can be stored for several months in a cool, dry place. However, without a specific storage environment, it is difficult to provide an exact shelf life estimate.
# Analysis Output for the captured frame:
# - **For packaged products:**
#   - **Product Name:** Chatpata Mixtures
#   - **Product Category:** Snacks
#   - **Product Quantity:** 20g
#   - **Product Count:** 1
#   - **Expiry Date:** 06/12/25
#
# - **For fruits and vegetables:**
#   - **Type of fruit/vegetable:** None
#   - **Freshness Index:** Not applicable
#   - **Estimated Shelf Life:** Not applicable
# Analysis Output for the captured frame:
# - **Product Name**: Biscuits
# - **Product Category**: Biscuits
# - **Product Quantity**: 1
# - **Product Count**: 1
# - **Expiry Date**: Not visible in the image
#
# - **For packaged products**:
#   - **Product Name**: Biscuits
#   - **Product Category**: Biscuits
#   - **Product Quantity**: 1
#   - **Product Count**: 1
#   - **Expiry Date**: Not visible in the image
#
# - **For fruits and vegetables**:
#   - **Type of fruit/vegetable**: Not applicable
#   - **Freshness Index**: Not applicable
#   - **Estimated Shelf Life**: Not applicable
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Unspecified
#   - Product Category: Snack
#   - Product Quantity: 1
#   - Product Count: 1
#   - Expiry Date: Not applicable (as it is a packaged product)
#
# - For fruits and vegetables:
#   - Type of fruit/vegetable: Not applicable (as it is a packaged product)
#   - Freshness Index: Not applicable (as it is a packaged product)
#   - Estimated Shelf Life: Not applicable (as it is a packaged product)
# Analysis Output for the captured frame:
# - **For packaged products:**
#   - **Product Name:** Diet Chivda
#   - **Product Category:** Snacks
#   - **Product Quantity:** 1 pack
#   - **Product Count:** 1
#   - **Expiry Date:** Not visible in the image
#
# - **For fruits and vegetables:**
#   - **Type of fruit/vegetable:** Not applicable as it is a packaged product
#   - **Freshness Index:** Not applicable as it is a packaged product
#   - **Estimated Shelf Life:** Not applicable as it is a packaged product
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Baked Sandwich Biscuits
#   - Product Category: Biscuits
#   - Product Quantity: 1
#   - Product Count: 1
#   - Expiry Date: 17/1/25 11:08
# Analysis Output for the captured frame:
# - For packaged products:
#   - Product Name: Haldiram's All in One
#   - Product Category: Snacks
#   - Product Quantity: 1 pack
#   - Product Count: 1
#   - Expiry Date: Not visible in the image
#
# - For fruits and vegetables:
#   - Type of fruit/vegetable: Not applicable, as the image shows a packaged snack product
#   - Freshness Index: Not applicable, as the image does not provide any visual cues about freshness
#   - Estimated Shelf Life: Not applicable, as the image does not provide any information about the shelf life of the product
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c0fb2fb273b8> in <cell line: 21>()
#      73
#      74         # Generate output from the model
# ---> 75         output_ids = model.generate(**inputs, max_new_tokens=1024)
#      76
#      77         # Decode the generated output
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2251
#    2252             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2253             result = self._sample(
#    2254                 input_ids,
#    2255                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3253                 is_prefill = False
#    3254             else:
# -> 3255                 outputs = model_forward(**model_inputs, return_dict=True)
#    3256
#    3257             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/qwen2_vl/modeling_qwen2_vl.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, pixel_values, pixel_values_videos, image_grid_thw, video_grid_thw, rope_deltas, cache_position)
#    1693                 position_ids = position_ids.unsqueeze(0).expand(3, -1, -1)
#    1694
# -> 1695         outputs = self.model(
#    1696             input_ids=None,
#    1697             position_ids=position_ids,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/qwen2_vl/modeling_qwen2_vl.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1128                 )
#    1129             else:
# -> 1130                 layer_outputs = decoder_layer(
#    1131                     hidden_states,
#    1132                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/qwen2_vl/modeling_qwen2_vl.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     860
#     861         # Self Attention
# --> 862         hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     863             hidden_states=hidden_states,
#     864             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/qwen2_vl/modeling_qwen2_vl.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings)
#     745         bsz, q_len, _ = hidden_states.size()
#     746
# --> 747         query_states = self.q_proj(hidden_states)
#     748         key_states = self.k_proj(hidden_states)
#     749         value_states = self.v_proj(hidden_states)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
